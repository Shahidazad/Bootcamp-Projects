# %% [markdown]
# # Review management

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
from keras.datasets import imdb
from keras.preprocessing import sequence
import keras
import tensorflow as tf
import os
import numpy as np

VOCAB_SIZE = 88584

MAXLEN = 250
BATCH_SIZE = 64

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = VOCAB_SIZE)
train_data = sequence.pad_sequences(train_data, MAXLEN)
test_data = sequence.pad_sequences(test_data, MAXLEN)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(VOCAB_SIZE, 32),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(loss="binary_crossentropy",optimizer="rmsprop",metrics=['acc'])

history = model.fit(train_data, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 15s 12ms/step - loss: 0.4166 - acc: 0.8094 - val_loss: 0.2899 - val_acc: 0.8860
# Epoch 2/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.2393 - acc: 0.9099 - val_loss: 0.2792 - val_acc: 0.8864
# Epoch 3/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.1825 - acc: 0.9349 - val_loss: 0.2708 - val_acc: 0.8954
# Epoch 4/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.1503 - acc: 0.9464 - val_loss: 0.2977 - val_acc: 0.8928
# Epoch 5/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.1292 - acc: 0.9550 - val_loss: 0.3047 - val_acc: 0.8870
# Epoch 6/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.1081 - acc: 0.9632 - val_loss: 0.3471 - val_acc: 0.8846
# Epoch 7/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0975 - acc: 0.9675 - val_loss: 0.4326 - val_acc: 0.8726
# Epoch 8/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0856 - acc: 0.9725 - val_loss: 0.3202 - val_acc: 0.8904
# Epoch 9/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0768 - acc: 0.9758 - val_loss: 0.3637 - val_acc: 0.8902
# Epoch 10/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0676 - acc: 0.9786 - val_loss: 0.3294 - val_acc: 0.8834

# %%
# take unique words from text data and put it in to dictionary each word have specific value 
 
vocab = {}    
word_encoding = 1
def bag_of_words(text):
  global word_encoding

  words = text.lower().split(" ")  # create a list of all of the words in the text.
  bag = {}  # stores all of the encodings and their frequency

  for word in words:
    if word in vocab:
      encoding = vocab[word]  # get encoding from vocab
    else:
      vocab[word] = word_encoding
      encoding = word_encoding
      word_encoding += 1
    
    if encoding in bag:
      bag[encoding] += 1
    else:
      bag[encoding] = 1
  
  return bag

text = "this is a test to see if this test will work is is test a a"
bag = bag_of_words(text)
print(bag)      # Each word showing its frequency
print(vocab)
# Out:
# {1: 2, 2: 3, 3: 3, 4: 3, 5: 1, 6: 1, 7: 1, 8: 1, 9: 1}
# {'this': 1, 'is': 2, 'a': 3, 'test': 4, 'to': 5, 'see': 6, 'if': 7, 'will': 8, 'work': 9}

# %%
len(train_data[4])
# Out:
# 147

# %%
len(train_data[0])
# Out:
# 218

# %%
# len of data r different but NN we  work on same len data so we convt data in same length

# %%
train_data = sequence.pad_sequences(train_data, MAXLEN) # if words more than 250 trim words
test_data = sequence.pad_sequences(test_data, MAXLEN) # if words less than 250 add 0s

# %%
# model creation

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(VOCAB_SIZE, 32),
    tf.keras.layers.LSTM(32),  # 32 dimension of every single word
    tf.keras.layers.Dense(1, activation="sigmoid")
])       # output is more then 0.5 +ve review
     # output is less then 0.5 -ve review

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 32)          2834688
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 2,843,041
# Trainable params: 2,843,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train model and compile it

model.compile(loss="binary_crossentropy",optimizer="rmsprop",metrics=['acc'])  # loss function tells us that how far away we our from correct probability.

history = model.fit(train_data, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 16s 14ms/step - loss: 0.4237 - acc: 0.8037 - val_loss: 0.3483 - val_acc: 0.8482
# Epoch 2/10
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2414 - acc: 0.9074 - val_loss: 0.2682 - val_acc: 0.8924
# Epoch 3/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.1840 - acc: 0.9315 - val_loss: 0.2902 - val_acc: 0.8770
# Epoch 4/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.1524 - acc: 0.9446 - val_loss: 0.2762 - val_acc: 0.8882
# Epoch 5/10
# 625/625 [==============================] - 7s 12ms/step - loss: 0.1314 - acc: 0.9548 - val_loss: 0.3338 - val_acc: 0.8792
# Epoch 6/10
# 625/625 [==============================] - 8s 12ms/step - loss: 0.1121 - acc: 0.9606 - val_loss: 0.2950 - val_acc: 0.8882
# Epoch 7/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0958 - acc: 0.9667 - val_loss: 0.4353 - val_acc: 0.8792
# Epoch 8/10
# 625/625 [==============================] - 7s 12ms/step - loss: 0.0862 - acc: 0.9715 - val_loss: 0.3055 - val_acc: 0.8890
# Epoch 9/10
# 625/625 [==============================] - 9s 14ms/step - loss: 0.0766 - acc: 0.9758 - val_loss: 0.3735 - val_acc: 0.8844
# Epoch 10/10
# 625/625 [==============================] - 7s 11ms/step - loss: 0.0652 - acc: 0.9786 - val_loss: 0.3418 - val_acc: 0.8816

# %%
# tf.convert_to_tensor(train_data, dtype=tf.int32)
results = model.evaluate(test_data, test_labels)
print(results)
# Out:
# 782/782 [==============================] - 4s 6ms/step - loss: 0.3959 - acc: 0.8562
# [0.39589956402778625, 0.8561599850654602]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 32)          2834688
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 2,843,041
# Trainable params: 2,843,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Model save

# %%
## save model
save_path = './modelnlp.h5'
model.save(save_path)

# %%
## load tensorflow model
save_path = './modelnlp.h5'
model = keras.models.load_model(save_path)

# %%
word_index = imdb.get_word_index()

def encode_text(text):  # function to encode the text
  tokens = keras.preprocessing.text.text_to_word_sequence(text)  # text will convert into individual tokens
  tokens = [word_index[word] if word in word_index else 0 for word in tokens]
  return sequence.pad_sequences([tokens], MAXLEN)[0]

text = "that movie was just amazing, so amazing"
encoded = encode_text(text)
print(encoded.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step
# (250,)

# %%
# make a decode function
# Go to word from  integer

reverse_word_index = {value: key for (key, value) in word_index.items()}

def decode_integers(integers):
    PAD = 0
    text = ""
    for num in integers:
      if num != PAD:  # num is not zero
        text += reverse_word_index[num] + " "

    return text[:-1]
  
print(decode_integers(encoded))
# Out:
# that movie was just amazing so amazing

# %%
#  make a prediction function

def predict(text):
  encoded_text = encode_text(text)  # encode the text 
  pred = np.zeros((1,250))         # 
  pred[0] = encoded_text
  # print(pred)
  # print(pred.shape)
  result = model.predict(pred) # input of model (1,250)
  # print(result[0])        # probability of prediction
  if result[0]>=0.5:
    print('Positive Review')
  else:
    print('Negative Review')
  # print(result)
  # print(result[0])   # +ve review value is more then 0.5
                     # -ve review value is less then 0.5
review_1 = "That movie was! really loved it and would great watch it again because it was amazingly great"
predict(review_1)

review_2 = "that movie really sucked. I hated it and wouldn't watch it again. Was one of the worst things I've ever watched"
predict(review_2)
# Out:
# Positive Review
# Negative Review

# %%
review_1_0='very nice hotel i will go again'
predict(review_1_0)
# Out:
# Positive Review

# %%
review_0='very nice movie'
predict(review_0)
# Out:
# Positive Review

# %%
review_0='worst movie'
predict(review_0)
# Out:
# Negative Review

# %%
review_0='i will never see this movie'
predict(review_0)# negative review
# Out:
# Negative Review

# %%
review_3="An excellent movie that I enjoyed a lot"
predict(review_3)
# Out:
# Positive Review

# %%
review_5=" can one make such a horrible movie? there is no story, but the acting of hero was very good"
predict(review_5)
# Out:
# [[0.57212216]]
# Positive Review

# %%
review_4 ="This is the worst movie I have ever seen oh shit"
predict(review_4)
# Out:
# Negative Review

# %%
review_5="the acting of hero was very good"
predict(review_5)
# Out:
# Positive Review
